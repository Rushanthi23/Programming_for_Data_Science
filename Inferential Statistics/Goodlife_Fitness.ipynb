# %% [markdown]
# # Descriptive Statistics - Goodlife Fitness Case Study
# ## Context :
# The market research team at Golden Ratio is assigned the task to identify customer profiles for each membership offered by Goodlife Fitness. The market research team decides to investigate whether there are differences across the membership options with respect to customer characteristics. The team decides to collect data on individuals who purchased a membership at a Goodlife Fitness. The data is stored in the GoodlifeFitness.csv file.
#
# ## Objective :
# Perform descriptive analysis to create a customer profile for each Goodlife Fitness membership option.
#
# ### The team identifies the following customer variables to study:
#   - Type: Basic, Care, or Premium membership options
#   - Age: Age of the customer in years
#   - Gender: Male or Female
#   - Education: Education of the customer in years
#   - MaritalStatus: Single or partnered
#   - WeeklyUse: The average number of times the customer plans to visit the gym each week
#   - Fitness: Self-rated fitness on an 1-to-5 scale, where 1 is poor shape and 5 is excellent shape.
#   - Income: Annual household income
#   - Kms: Average number of kms the customer expects to walk/run each week

# %% [markdown]
# ### Import the necessary libraries

# %%
# Load the necessary packages
import pandas as pd

# %% [markdown]
# ### Read the dataset

# %%
# Load the GoodlifeFitness.csv Dataset
data = pd.read_csv('GoodlifeFitness.csv')

# %%
# check the type of the data variable
type(data)
# Out:
# pandas.core.frame.DataFrame

# %%
# check first 10 rows in the dataframe
data.head(10)
# Out:
#     Type  Age  Gender  Education MaritalStatus  WeeklyUse  Fitness  Income  \
# 0  Basic   18    Male         14        Single          3        4   29562
# 1  Basic   19    Male         15        Single          2        3   31836
# 2  Basic   19  Female         14     Partnered          4        3   30699
# 3  Basic   19    Male         12        Single          3        3   32973
# 4  Basic   20    Male         13     Partnered          4        2   35247
# 5  Basic   20  Female         14     Partnered          3        3   32973
# 6  Basic   21  Female         14     Partnered          3        3   35247
# 7  Basic   21    Male         13        Single          3        3   32973
# 8  Basic   21    Male         15        Single          5        4   35247
# 9  Basic   21  Female         15     Partnered          2        3   37521
#
#    Kms
# 0  180
# 1  121
# 2  106
# 3  137
# 4   76
# 5  106
# 6  121
# 7  137
# 8  227
# 9  137

# %% [markdown]
# ### Printing the basic information

# %%
# check for nulls and other basic info from the data
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 180 entries, 0 to 179
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Type           180 non-null    object
#  1   Age            180 non-null    int64
#  2   Gender         180 non-null    object
#  3   Education      180 non-null    int64
#  4   MaritalStatus  180 non-null    object
#  5   WeeklyUse      180 non-null    int64
#  6   Fitness        180 non-null    int64
#  7   Income         180 non-null    int64
#  8   Kms            180 non-null    int64
# dtypes: int64(6), object(3)
# memory usage: 12.8+ KB

# %% [markdown]
# **Observations:**
# - There are 180 observations and 9 columns (6 of them are numerical and 3 are categorical).
# - All the column have 180 non-null values i.e. there are no missing values in the data.

# %% [markdown]
# ## <span style="color:crimson">Univariate Analysis</span>

# %% [markdown]
# ### Check the five point summary statistics

# %%
# check analytical summary of the dataset
data.describe()
# Out:
#               Age   Education   WeeklyUse     Fitness         Income  \
# count  180.000000  180.000000  180.000000  180.000000     180.000000
# mean    28.788889   15.572222    3.455556    3.311111   53719.577778
# std      6.943498    1.617055    1.084797    0.958869   16506.684226
# min     18.000000   12.000000    2.000000    1.000000   29562.000000
# 25%     24.000000   14.000000    3.000000    3.000000   44058.750000
# 50%     26.000000   16.000000    3.000000    3.000000   50596.500000
# 75%     33.000000   16.000000    4.000000    4.000000   58668.000000
# max     50.000000   21.000000    7.000000    5.000000  104581.000000
#
#               Kms
# count  180.000000
# mean   166.127778
# std     83.438067
# min     34.000000
# 25%    106.000000
# 50%    151.000000
# 75%    184.750000
# max    579.000000

# %% [markdown]
# **Observations:**
#
# - Average age of customers is 29 years. And, the age ranges from 18 to 50.
# - The average annual income of a customer is 53K. It has a range of values from 30K to 104K, which again shows a good diversity of customers.
# - Median gym usage is 3 days, that means 50% of the cutstomer are going to use the gym for less than or equal to 3 days in a week.

# %%
# check stats for categorical data, include all gives everything in one table instead we do object to give description of object type only
data.describe(include='object')
# unique is the number of class, top - the highest number of category, freq - the total number of top values.
# Out:
#          Type Gender MaritalStatus
# count     180    180           180
# unique      3      2             2
# top     Basic   Male     Partnered
# freq       80    104           107

# %%
data.describe(include='all')
# Out:
#          Type         Age Gender   Education MaritalStatus   WeeklyUse  \
# count     180  180.000000    180  180.000000           180  180.000000
# unique      3         NaN      2         NaN             2         NaN
# top     Basic         NaN   Male         NaN     Partnered         NaN
# freq       80         NaN    104         NaN           107         NaN
# mean      NaN   28.788889    NaN   15.572222           NaN    3.455556
# std       NaN    6.943498    NaN    1.617055           NaN    1.084797
# min       NaN   18.000000    NaN   12.000000           NaN    2.000000
# 25%       NaN   24.000000    NaN   14.000000           NaN    3.000000
# 50%       NaN   26.000000    NaN   16.000000           NaN    3.000000
# 75%       NaN   33.000000    NaN   16.000000           NaN    4.000000
# max       NaN   50.000000    NaN   21.000000           NaN    7.000000
#
#            Fitness         Income         Kms
# count   180.000000     180.000000  180.000000
# unique         NaN            NaN         NaN
# top            NaN            NaN         NaN
# freq           NaN            NaN         NaN
# mean      3.311111   53719.577778  166.127778
# std       0.958869   16506.684226   83.438067
# min       1.000000   29562.000000   34.000000
# 25%       3.000000   44058.750000  106.000000
# 50%       3.000000   50596.500000  151.000000
# 75%       4.000000   58668.000000  184.750000
# max       5.000000  104581.000000  579.000000

# %% [markdown]
# ### Plotting distribution for numerical columns

# %%
# Plot the distribution of Age
data['Age'].plot(kind = 'hist')
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
#to give skew type line
data['Age'].plot(kind ='kde')
# Out:
# <AxesSubplot:ylabel='Density'>

# %% [markdown]
# **Observations**
# - The age distribution is also right skewed. there are few people with age greater than 40 who focus on their fitness.
# - Most of the customers are aged between 20 to 30, which signifies the people who are young tend to hit the gym more.

# %%
# plotting a boxplot for Age
data.boxplot(column='Age', vert = False)
# because the chart is right skewed, that's why the outliers are towards the left
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## <span style="color:crimson">Bivariate analysis</span>

# %%
# plot a boxplot of income by membership type
data.boxplot(column='Income', by='Type', vert = False)
# Out:
# <AxesSubplot:title={'center':'Income'}, xlabel='Type'>

# %% [markdown]
# **Observation**
# - Premium membership is bought by the people having an income range from 60K to 90k.
# - Basic membership is mostly consider by the people who have lower income level.

# %% [markdown]
# ##  <span style="color:crimson">Multi-Variate Analysis</span>

# %%
# Using .crosstab analyse data across Type, Gender, and MaritalStatus
pd.crosstab(data['Type'],[data['Gender'], data['MaritalStatus']])
# first column is the index, then we pass the columns as a list
# Out:
# Gender           Female             Male
# MaritalStatus Partnered Single Partnered Single
# Type
# Basic                27     13        21     19
# Care                 15     14        21     10
# Premium               4      3        19     14

# %%
pd.crosstab(data['Type'],[data['Gender']])
# Out:
# Gender   Female  Male
# Type
# Basic        40    40
# Care         29    31
# Premium       7    33

# %% [markdown]
# **Observation:**
# - It can be clearly seen from the table that the Basic membership is popular among both males and females.
# - Premium membership is popular among males.
#
# **Inference:**
# - Market premium memberships to Male customers.

# %%
# using .pivot_table analyze data by membership type and income
pd.pivot_table(data, values='Income', index=['Type'])
# Out:
#             Income
# Type
# Basic    46418.025
# Care     48973.650
# Premium  75441.575

# %% [markdown]
# **Observations:**
# - The average income of customers who bought Basic and Care is on the lower side as compared to the customers who bought Premium memberships.
# - The people who bought Premium memberships, there is a big difference in the income level of the people
#
# **Inference:**
# - The Income variable is a good predictor to find the preference of the customers.

# %% [markdown]
# #### Let's check the exact value of correlation between the variables using correlation martix.

# %%
#Correlation matrix will compare with continuous variables
data.corr()
# Out:
#                 Age  Education  WeeklyUse   Fitness    Income       Kms
# Age        1.000000   0.280496   0.015064  0.061105  0.513414  0.036400
# Education  0.280496   1.000000   0.395155  0.410581  0.625827  0.307264
# WeeklyUse  0.015064   0.395155   1.000000  0.668606  0.519537  0.759018
# Fitness    0.061105   0.410581   0.668606  1.000000  0.535005  0.785404
# Income     0.513414   0.625827   0.519537  0.535005  1.000000  0.543094
# Kms        0.036400   0.307264   0.759018  0.785404  0.543094  1.000000

# %%
# Scatter plot using Pandas
data.plot.scatter('Age', 'WeeklyUse')
# Out:
# <AxesSubplot:xlabel='Age', ylabel='WeeklyUse'>

# %%
data.plot.scatter('Age', 'Income')
# Out:
# <AxesSubplot:xlabel='Age', ylabel='Income'>

# %% [markdown]
# **Observations:**
# - Kms and WeeklyUse , kms and Fitness are highly correlated with each other, which makes sense as more useage, leads to more kms hence results better fitness.
# - There is a high correlation between income and education too, signifies that the people with good education level tend to have higher income.
# - Fitness and WeeklyUse are also highly correlated.

# %% [markdown]
# ### Conclusions:
# - Premium membership is the least sold product among the three. Also, it is preferred by customers who are planning to run more, having good fitness, and higher income range.
# - Basic Membership is most popular which is preferred among customers having lower income range.
# - Care Membership is slightly less popular than Basic.

# %%
import seaborn as sns

# %%
import matplotlib.pyplot as plt

# display plots in the notebook
# %matplotlib inline

# %%
plt.pie(x = 'Age', data=data)
# Out:
# ([<matplotlib.patches.Wedge at 0x20fbc5857c0>,
#   <matplotlib.patches.Wedge at 0x20fbc749250>,
#   <matplotlib.patches.Wedge at 0x20fbc75b7f0>,
#   <matplotlib.patches.Wedge at 0x20fbce8c280>,
#   <matplotlib.patches.Wedge at 0x20fbc76edc0>,
#   <matplotlib.patches.Wedge at 0x20fbd0283a0>,
#   <matplotlib.patches.Wedge at 0x20fbd028c70>,
#   <matplotlib.patches.Wedge at 0x20fbce7a040>,
#   <matplotlib.patches.Wedge at 0x20fbc5a40a0>,
#   <matplotlib.patches.Wedge at 0x20fbc62d9a0>,
#   <matplotlib.patches.Wedge at 0x20fbc585340>,
#   <matplotlib.patches.Wedge at 0x20fbcb20850>,
#   <matplotlib.patches.Wedge at 0x20fbd02a250>,
#   <matplotlib.patches.Wedge at 0x20fbd02a8e0>,
#   <matplotlib.patches.Wedge at 0x20fbd02adc0>,
#   <matplotlib.patches.Wedge at 0x20fbce693a0>,
#   <matplotlib.patches.Wedge at 0x20fbce69e80>,
#   <matplotlib.patches.Wedge at 0x20fbe5ef490>,
#   <matplotlib.patches.Wedge at 0x20fbe5ef970>,
#   <matplotlib.patches.Wedge at 0x20fbe5efe50>,
#   <matplotlib.patches.Wedge at 0x20fbe606370>,
#   <matplotlib.patches.Wedge at 0x20fbe606850>,
#   <matplotlib.patches.Wedge at 0x20fbcb1cfd0>,
#   <matplotlib.patches.Wedge at 0x20fbd02a2b0>,
#   <matplotlib.patches.Wedge at 0x20fbce7a400>,
#   <matplotlib.patches.Wedge at 0x20fbce6cd60>,
#   <matplotlib.patches.Wedge at 0x20fbcb00b80>,
#   <matplotlib.patches.Wedge at 0x20fbce8c340>,
#   <matplotlib.patches.Wedge at 0x20fbc638e20>,
#   <matplotlib.patches.Wedge at 0x20fbc62d670>,
#   <matplotlib.patches.Wedge at 0x20fbd028a60>,
#   <matplotlib.patches.Wedge at 0x20fbc76c9a0>,
#   <matplotlib.patches.Wedge at 0x20fbc76e640>,
#   <matplotlib.patches.Wedge at 0x20fbc76ebe0>,
#   <matplotlib.patches.Wedge at 0x20fbce5c9d0>,
#   <matplotlib.patches.Wedge at 0x20fbce5c160>,
#   <matplotlib.patches.Wedge at 0x20fbd147040>,
#   <matplotlib.patches.Wedge at 0x20fbd147520>,
#   <matplotlib.patches.Wedge at 0x20fbd147a00>,
#   <matplotlib.patches.Wedge at 0x20fbd147ee0>,
#   <matplotlib.patches.Wedge at 0x20fbd15d400>,
#   <matplotlib.patches.Wedge at 0x20fbd15d8e0>,
#   <matplotlib.patches.Wedge at 0x20fbd15ddc0>,
#   <matplotlib.patches.Wedge at 0x20fbd1802e0>,
#   <matplotlib.patches.Wedge at 0x20fbd1807c0>,
#   <matplotlib.patches.Wedge at 0x20fbd180ca0>,
#   <matplotlib.patches.Wedge at 0x20fbe2af1c0>,
#   <matplotlib.patches.Wedge at 0x20fbe2af6a0>,
#   <matplotlib.patches.Wedge at 0x20fbe2afb80>,
#   <matplotlib.patches.Wedge at 0x20fbe2c00a0>,
#   <matplotlib.patches.Wedge at 0x20fbe2c0580>,
#   <matplotlib.patches.Wedge at 0x20fbe2c0a60>,
#   <matplotlib.patches.Wedge at 0x20fbe2c0f40>,
#   <matplotlib.patches.Wedge at 0x20fbe423460>,
#   <matplotlib.patches.Wedge at 0x20fbe423940>,
#   <matplotlib.patches.Wedge at 0x20fbe423e20>,
#   <matplotlib.patches.Wedge at 0x20fbe434340>,
#   <matplotlib.patches.Wedge at 0x20fbe434820>,
#   <matplotlib.patches.Wedge at 0x20fbe434d00>,
#   <matplotlib.patches.Wedge at 0x20fbe458220>,
#   <matplotlib.patches.Wedge at 0x20fbe458700>,
#   <matplotlib.patches.Wedge at 0x20fbe458be0>,
#   <matplotlib.patches.Wedge at 0x20fbe4b2100>,
#   <matplotlib.patches.Wedge at 0x20fbe4b25e0>,
#   <matplotlib.patches.Wedge at 0x20fbe4b2ac0>,
#   <matplotlib.patches.Wedge at 0x20fbe4b2fa0>,
#   <matplotlib.patches.Wedge at 0x20fbe4cf4c0>,
#   <matplotlib.patches.Wedge at 0x20fbe4cf9a0>,
#   <matplotlib.patches.Wedge at 0x20fbe4cfe80>,
#   <matplotlib.patches.Wedge at 0x20fbe52b3a0>,
#   <matplotlib.patches.Wedge at 0x20fbe52b880>,
#   <matplotlib.patches.Wedge at 0x20fbe52bd60>,
#   <matplotlib.patches.Wedge at 0x20fbe548280>,
#   <matplotlib.patches.Wedge at 0x20fbe548760>,
#   <matplotlib.patches.Wedge at 0x20fbe548c40>,
#   <matplotlib.patches.Wedge at 0x20fbd199160>,
#   <matplotlib.patches.Wedge at 0x20fbd199640>,
#   <matplotlib.patches.Wedge at 0x20fbd199b20>,
#   <matplotlib.patches.Wedge at 0x20fbd1ae040>,
#   <matplotlib.patches.Wedge at 0x20fbd1ae520>,
#   <matplotlib.patches.Wedge at 0x20fbd1aea00>,
#   <matplotlib.patches.Wedge at 0x20fbd1aeee0>,
#   <matplotlib.patches.Wedge at 0x20fbd1c8400>,
#   <matplotlib.patches.Wedge at 0x20fbd1c88e0>,
#   <matplotlib.patches.Wedge at 0x20fbd1c8dc0>,
#   <matplotlib.patches.Wedge at 0x20fbd1e92e0>,
#   <matplotlib.patches.Wedge at 0x20fbd1e97c0>,
#   <matplotlib.patches.Wedge at 0x20fbd1e9ca0>,
#   <matplotlib.patches.Wedge at 0x20fbd2011c0>,
#   <matplotlib.patches.Wedge at 0x20fbd2016a0>,
#   <matplotlib.patches.Wedge at 0x20fbd201b80>,
#   <matplotlib.patches.Wedge at 0x20fbd21a0a0>,
#   <matplotlib.patches.Wedge at 0x20fbd21a580>,
#   <matplotlib.patches.Wedge at 0x20fbd21aa60>,
#   <matplotlib.patches.Wedge at 0x20fbd21af40>,
#   <matplotlib.patches.Wedge at 0x20fbd237460>,
#   <matplotlib.patches.Wedge at 0x20fbd237940>,
#   <matplotlib.patches.Wedge at 0x20fbd237e20>,
#   <matplotlib.patches.Wedge at 0x20fbd24c340>,
#   <matplotlib.patches.Wedge at 0x20fbd24c850>,
#   <matplotlib.patches.Wedge at 0x20fbd24cd30>,
#   <matplotlib.patches.Wedge at 0x20fbe236250>,
#   <matplotlib.patches.Wedge at 0x20fbe236730>,
#   <matplotlib.patches.Wedge at 0x20fbe236c10>,
#   <matplotlib.patches.Wedge at 0x20fbe258130>,
#   <matplotlib.patches.Wedge at 0x20fbe258610>,
#   <matplotlib.patches.Wedge at 0x20fbe258af0>,
#   <matplotlib.patches.Wedge at 0x20fbe258fd0>,
#   <matplotlib.patches.Wedge at 0x20fbe26a4f0>,
#   <matplotlib.patches.Wedge at 0x20fbe26a9d0>,
#   <matplotlib.patches.Wedge at 0x20fbe26aeb0>,
#   <matplotlib.patches.Wedge at 0x20fbe2853d0>,
#   <matplotlib.patches.Wedge at 0x20fbe2858b0>,
#   <matplotlib.patches.Wedge at 0x20fbe285d90>,
#   <matplotlib.patches.Wedge at 0x20fbe2f52b0>,
#   <matplotlib.patches.Wedge at 0x20fbe2f5790>,
#   <matplotlib.patches.Wedge at 0x20fbe2f5c70>,
#   <matplotlib.patches.Wedge at 0x20fbe30e190>,
#   <matplotlib.patches.Wedge at 0x20fbe30e670>,
#   <matplotlib.patches.Wedge at 0x20fbe30eb50>,
#   <matplotlib.patches.Wedge at 0x20fbe318070>,
#   <matplotlib.patches.Wedge at 0x20fbe318550>,
#   <matplotlib.patches.Wedge at 0x20fbe318a30>,
#   <matplotlib.patches.Wedge at 0x20fbe318f10>,
#   <matplotlib.patches.Wedge at 0x20fbe32e430>,
#   <matplotlib.patches.Wedge at 0x20fbe32e910>,
#   <matplotlib.patches.Wedge at 0x20fbe32edf0>,
#   <matplotlib.patches.Wedge at 0x20fbe34c310>,
#   <matplotlib.patches.Wedge at 0x20fbe34c7f0>,
#   <matplotlib.patches.Wedge at 0x20fbe34ccd0>,
#   <matplotlib.patches.Wedge at 0x20fbe3691f0>,
#   <matplotlib.patches.Wedge at 0x20fbe3696d0>,
#   <matplotlib.patches.Wedge at 0x20fbe369bb0>,
#   <matplotlib.patches.Wedge at 0x20fbe3810d0>,
#   <matplotlib.patches.Wedge at 0x20fbe3815b0>,
#   <matplotlib.patches.Wedge at 0x20fbe381ac0>,
#   <matplotlib.patches.Wedge at 0x20fbe381fa0>,
#   <matplotlib.patches.Wedge at 0x20fbe3a74c0>,
#   <matplotlib.patches.Wedge at 0x20fbe3a79a0>,
#   <matplotlib.patches.Wedge at 0x20fbe3a7e80>,
#   <matplotlib.patches.Wedge at 0x20fbe3b73a0>,
#   <matplotlib.patches.Wedge at 0x20fbe3b7880>,
#   <matplotlib.patches.Wedge at 0x20fbe3b7d60>,
#   <matplotlib.patches.Wedge at 0x20fbe3da280>,
#   <matplotlib.patches.Wedge at 0x20fbe3da760>,
#   <matplotlib.patches.Wedge at 0x20fbe3dac40>,
#   <matplotlib.patches.Wedge at 0x20fbe3eb160>,
#   <matplotlib.patches.Wedge at 0x20fbe3eb640>,
#   <matplotlib.patches.Wedge at 0x20fbe3ebb20>,
#   <matplotlib.patches.Wedge at 0x20fbe407040>,
#   <matplotlib.patches.Wedge at 0x20fbe407520>,
#   <matplotlib.patches.Wedge at 0x20fbe407a00>,
#   <matplotlib.patches.Wedge at 0x20fbe407ee0>,
#   <matplotlib.patches.Wedge at 0x20fbe460400>,
#   <matplotlib.patches.Wedge at 0x20fbe4608e0>,
#   <matplotlib.patches.Wedge at 0x20fbe460dc0>,
#   <matplotlib.patches.Wedge at 0x20fbe4822e0>,
#   <matplotlib.patches.Wedge at 0x20fbe4827c0>,
#   <matplotlib.patches.Wedge at 0x20fbe482ca0>,
#   <matplotlib.patches.Wedge at 0x20fbe4941c0>,
#   <matplotlib.patches.Wedge at 0x20fbe4946a0>,
#   <matplotlib.patches.Wedge at 0x20fbe494b80>,
#   <matplotlib.patches.Wedge at 0x20fbe5720a0>,
#   <matplotlib.patches.Wedge at 0x20fbe572580>,
#   <matplotlib.patches.Wedge at 0x20fbe572a60>,
#   <matplotlib.patches.Wedge at 0x20fbe572f40>,
#   <matplotlib.patches.Wedge at 0x20fbe591460>,
#   <matplotlib.patches.Wedge at 0x20fbe591940>,
#   <matplotlib.patches.Wedge at 0x20fbe591e20>,
#   <matplotlib.patches.Wedge at 0x20fbe5a8340>,
#   <matplotlib.patches.Wedge at 0x20fbe5a8820>,
#   <matplotlib.patches.Wedge at 0x20fbe5a8d00>,
#   <matplotlib.patches.Wedge at 0x20fbe5c2220>,
#   <matplotlib.patches.Wedge at 0x20fbe5c2700>,
#   <matplotlib.patches.Wedge at 0x20fbe5c2be0>,
#   <matplotlib.patches.Wedge at 0x20fbe4e2100>,
#   <matplotlib.patches.Wedge at 0x20fbe4e25e0>,
#   <matplotlib.patches.Wedge at 0x20fbe4e2ac0>,
#   <matplotlib.patches.Wedge at 0x20fbe4e2fa0>,
#   <matplotlib.patches.Wedge at 0x20fbe4f74c0>],
#  [Text(1.09993450497073, 0.012003531763405264, ''),
#   Text(1.099388561507648, 0.03667138974929489, ''),
#   Text(1.098252092370002, 0.06198662440327283, ''),
#   Text(1.0965327757026804, 0.08726896246533221, ''),
#   Text(1.0941631166334733, 0.11316834450907465, ''),
#   Text(1.091097345330665, 0.13966596941408513, ''),
#   Text(1.087289082974651, 0.16674066703759632, ''),
#   Text(1.0826914523343887, 0.1943687707479067, ''),
#   Text(1.0773919062738344, 0.221870864007948, ''),
#   Text(1.0713938805207688, 0.24922911704423498, ''),
#   Text(1.0645334846213783, 0.2770712184978181, ''),
#   Text(1.0567647578783987, 0.3053657585686541, ''),
#   Text(1.0482441263176483, 0.33344302607874465, ''),
